# %%
import pandas as pd

# %%
from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; }</style>")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
x_df = pd.read_csv("C:/Users/jbadiabo/PycharmProjects/Bet-on-Sibyl/Football/FootballTop5/FootballTop5_Upcoming_Matchups_EU_P_df.csv")

# %%
x_df
# Out:
#     ID        Date      Time            League  \
# 0    0  2017-01-13  20:45:00           ligue-1
# 1    1  2017-01-14  17:00:00           ligue-1
# 2    2  2017-01-14  20:00:00           ligue-1
# 3    3  2017-01-14  20:00:00           ligue-1
# 4    4  2017-01-14  20:00:00           ligue-1
# 5    5  2017-01-14  20:00:00           ligue-1
# 6    6  2017-01-14  20:00:00           ligue-1
# 7    7  2017-01-15  15:00:00           ligue-1
# 8    8  2017-01-15  17:00:00           ligue-1
# 9    9  2017-01-15  21:00:00           ligue-1
# 10  10  2017-01-18  20:00:00           ligue-1
# 11  11  2017-01-21  17:00:00           ligue-1
# 12  12  2017-01-21  20:00:00           ligue-1
# 13  13  2017-01-21  20:00:00           ligue-1
# 14  14  2017-01-21  20:00:00           ligue-1
# 15  15  2017-01-21  20:00:00           ligue-1
# 16  16  2017-01-21  20:00:00           ligue-1
# 17  17  2017-01-28  20:00:00           ligue-1
# 18  18  2017-01-28  20:00:00           ligue-1
# ...

# %%
HTML(x_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>League</th>
#       <th>Matchup_US_P</th>
#       <th>Home_Team</th>
#       <th>Visitor_Team</th>
#       <th>Home_Odd</th>
#       <th>Draw_Odd</th>
#       <th>Visitor_Odd</th>
#       <th>Bookies_choice</th>
#       <th>Sibyl</th>
#       <th>Confidence</th>
#       <th>Divergence_Y/N</th>
#       <th>True_Result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2017-01-13</td>
#       <td>20:45:00</td>
#       <td>ligue-1</td>
#       <td>OSC Lille vs AS St. Etienne</td>
#       <td>OSC Lille</td>
#       <td>AS St. Etienne</td>
#       <td>2.37</td>
#       <td>3.00</td>
#       <td>3.34</td>
#       <td>Lille</td>
#       <td>Lille</td>
#       <td>0.375</td>
#       <td>N</td>
#       <td>Upcoming</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...
