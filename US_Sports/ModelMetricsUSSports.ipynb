# %%
import datetime as dt
import dateutil.relativedelta
from pandas import *
import itertools


class ModelMetricsUSSports(object):
    def __init__(self, us_sports_tableau_filename, us_sports_upco_matchups_us_p_filename,
                 us_sports_team_name_filename):
        self.us_sports_tableau_filename = us_sports_tableau_filename
        self.us_sports_upco_matchups_us_p_filename = us_sports_upco_matchups_us_p_filename
        self.us_sports_team_name_filename = us_sports_team_name_filename
        # -------------------------------------------------------
        self.mlb_tableau_df = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\MLB\mlb_tableau_input_2016.csv")
        self.nba_tableau_df = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NBA\\nba_tableau_output_2017.csv")
        self.nfl_tableau_df = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NFL\\nfl_tableau_output_2016.csv")
        self.nhl_tableau_df = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NHL\\nhl_tableau_output_2017.csv")
        # ------------------------------------------------------
        self.upco_nba = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NBA\\NBA_Upcoming_Matchups_US_P_df.csv")
        self.upco_nfl = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NFL\\NFL_Upcoming_Matchups_US_P_df.csv")
        self.upco_nhl = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NHL\\NHL_Upcoming_Matchups_US_P_df.csv")
        self.upco_mlb = read_csv(
            "C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\MLB\MLB_Upcoming_Matchups_US_P_df.csv")
        self.upco_mlb['League'] = 'MLB'
        self.upco_mlb['True_Result'] = self.upco_mlb['True_Result_U']
        self.upco_mlb.drop('True_Result_U', axis=1, inplace=True)
        # ------------------------------------------------------
        self.mlb_team_stat_df = read_csv(
            'C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\MLB\mlb_team_stats_2016.csv')
        self.nba_team_stat_df = read_csv(
            'C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NBA\\nba_team_stats_2017_2017.csv')
        self.nba_team_stat_df['Tm'] = self.nba_team_stat_df['Team']
        self.nfl_team_stat_df = read_csv(
            'C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NFL\\nfl_team_stats_2016_2016.csv')
        self.nhl_team_stat_df = read_csv(
            'C:\Users\jbadiabo\PycharmProjects\Sibyl\US_Sports\NHL\\nhl_team_stats_2017_2017.csv')

    def __call__(self):
        self.us_sports_tableau_df = self.get_tableau_df(self.mlb_tableau_df, self.nba_tableau_df, self.nfl_tableau_df,
                                                        self.nhl_tableau_df)
        self.us_sports_upco_df = self.get_upco_df(self.upco_mlb, self.upco_nba, self.upco_nfl, self.upco_nhl)
        self.team_name_list = self.get_team_name_list(self.mlb_team_stat_df, self.nba_team_stat_df,
                                                      self.nfl_team_stat_df, self.nhl_team_stat_df)
        self.us_sports_team_names_list = list(itertools.chain.from_iterable(self.team_name_list))
        self.us_sports_team_names_df = DataFrame(self.us_sports_team_names_list, columns=['Tm'])
        # -----------------------------------------------------------------------------

        self.us_sports_tableau_df.to_csv('us_sports_tableau_output.csv', mode='w+', index=False)
        self.us_sports_upco_df.to_csv('us_sports_upcoming_matchups_us_p_df.csv', mode='w+', index=False)
        self.us_sports_team_names_df.to_csv('us_sports_team_names_list.csv', mode='w+', index=False)
        # -----------------------------------------------------------------------------
        self.get_metrics(self.us_sports_tableau_filename, self.us_sports_upco_matchups_us_p_filename,
                         self.us_sports_team_name_filename)

    def get_team_name_list(self, mlb_df, nba_df, nfl_df, nhl_df):
        concat_name_list = []

        for i in [mlb_df, nba_df, nfl_df, nhl_df]:
            concat_name_list.append(i['Tm'])

        return concat_name_list

    def get_tableau_df(self, mlb_tableau, nba_tableau, nfl_tableau, nhl_tableau):
        frames = [mlb_tableau, nba_tableau, nfl_tableau, nhl_tableau]

        us_sports_df = concat(frames)

        return us_sports_df

    def get_upco_df(self, up_mlb, up_nba, up_nfl, up_nhl):
        frames = [up_mlb, up_nba, up_nfl, up_nhl]

        us_sports_upco_df = concat(frames)

        return us_sports_upco_df

    def get_metrics(self, tableau_input_filename, matchup_output_us, cs_team_stats_filename):

        df = read_csv(tableau_input_filename)
        df['Confidence'] = df['Confidence'].round(3)
        df = df.sort_values('Date')
        df = df.drop('ID', axis=1)
        df = df.reset_index(drop=True)
        df['Date'] = to_datetime(df['Date'], format='%Y-%m-%d')

        # Adding the current datetime
        current_date = dt.datetime.today().strftime("%m/%d/%Y")

        # Replacing the 1s and 0s by the team names for predictions and results
        df['Predicted_Result'] = df.apply(lambda x: x['Home_Team'] if x['Predicted_Result'] == 1 else x['Visitor_Team'],
                                          axis=1)
        df['True_Result'] = df.apply(lambda x: x['Home_Team'] if x['True_Result'] == 1 else x['Visitor_Team'], axis=1)

        # Calculating the number of games for the current date
        today_games = df[(df['Date'] == current_date)]
        n_today_games = len(today_games)

        # Calculating the number of predictions made so far by Sibyl
        predictions_sofar = df[(df['Date'] <= current_date)]
        predictions_sofar = predictions_sofar.sort_values('Date')
        n_predictions_sofar = len(predictions_sofar)

        # Calculating the % of correct predictions made by Sibyl
        # based on all the previous games until current date (excluded)
        previous_games_df = df[(df['Date'] < current_date)]
        n_previous_games = len(previous_games_df)
        correct_predictions_df = previous_games_df[
            (previous_games_df['True_Result'] == previous_games_df['Predicted_Result'])]
        n_correct_pred = len(correct_predictions_df)
        perc_correct_pred = ((n_correct_pred / float(n_previous_games)) * 100)
        perc_correct_pred = float(format(perc_correct_pred, '.2f'))

        # Creating a df composed of games from one month ago until current date minus one day
        # -> filtered on games where Sibyl was right
        current_date_type_datetime = to_datetime(current_date, format="%m/%d/%Y")
        current_date_minus_one_month = current_date_type_datetime - dateutil.relativedelta.relativedelta(months=1,
                                                                                                         days=1)
        one_month_games_df = df[(df['Date'] < current_date) & (df['Date'] >= current_date_minus_one_month)]
        correct_predictions_one_month_ago_df = one_month_games_df[
            (one_month_games_df['True_Result'] == one_month_games_df['Predicted_Result'])]

        # Taking the current season team stats df to take the list of teams
        cs_team_stats_df = read_csv(cs_team_stats_filename)
        db_team_names_list = sorted(cs_team_stats_df['Tm'].tolist())
        teams = db_team_names_list

        # Determining the team of the month to bet on
        # When Sibyl tells they will win and they win... -> nb: % of win games in this case since one month
        best_team_as_chosen = ''

        best_perc_as_chosen = 0.0

        for team in teams:
            try:
                n_games_played_at_home = one_month_games_df.Home_Team.str.contains(team).sum()
                n_games_played_away = one_month_games_df.Visitor_Team.str.contains(team).sum()
                n_games_played = n_games_played_at_home + n_games_played_away

                wins_as_chosen = correct_predictions_one_month_ago_df.True_Result.str.contains(team).sum()

                perc_wins = (wins_as_chosen / float(n_games_played)) * 100
                perc_wins = float(format(perc_wins, '.2f'))

            except KeyError:
                pass

            if wins_as_chosen == 0:
                continue

            if perc_wins > best_perc_as_chosen:
                best_team_as_chosen = team
                best_perc_as_chosen = perc_wins

        # Creating a df composed of games from one month ago until current date minus one day
        # -> filtered on games where Sibyl was wrong
        mistakes_one_month_ago_df = one_month_games_df[
            (one_month_games_df['True_Result'] != one_month_games_df['Predicted_Result'])]
        # When Sibyl tells they will win and they end up to loose... -> nb: % of lost games in this case since one month
        worst_team_as_chosen = ''

        worst_perc_as_chosen = 0.0

        for team in teams:
            try:
                n_games_played_at_home = one_month_games_df.Home_Team.str.contains(team).sum()
                n_games_played_away = one_month_games_df.Visitor_Team.str.contains(team).sum()
                n_games_played = n_games_played_at_home + n_games_played_away

                lost_games_as_chosen = mistakes_one_month_ago_df.Predicted_Result.str.contains(team).sum()

                perc_lost_games = (lost_games_as_chosen / float(n_games_played)) * 100
                perc_lost_games = float(format(perc_lost_games, '.2f'))

            except KeyError:
                pass

            if lost_games_as_chosen == 0:
                continue

            if perc_lost_games > worst_perc_as_chosen:
                worst_team_as_chosen = team
                worst_perc_as_chosen = perc_lost_games

        # Top teams to bet on based on divergence strategy for the next matchups nb: US Presentation
        today_games_df_us = read_csv(matchup_output_us)
        today_games_df_us['Date'] = to_datetime(today_games_df_us['Date'], format='%Y-%m-%d')

        today_games_divstrat_df = today_games_df_us[(today_games_df_us['Divergence_Y/N'] == 'Y') & (
            today_games_df_us['Date'].dt.day >= current_date_type_datetime.day)]
        today_games_divstrat_df = today_games_divstrat_df.sort_values(['Date', 'Time'], ascending=True)
        today_games_divstrat_df = today_games_divstrat_df.drop_duplicates('Matchup_US_P')

        # Calculating the mean confidence of Sibyl in the case of divergence games
        mean_sibyl_conf_for_divstrat = today_games_divstrat_df['Confidence'].mean()

        # Putting the calculated values into dfs
        sibyl_metrics_df = DataFrame(
            columns=['N_Today_games', 'N_Predictions_made', 'Sea_Perc_corr_pred', 'Mean_Sibyl_conf_for_divstrat'])
        month_teams_df = DataFrame(
            columns=['Team_of_the_month', 'Best_percent_as_chosen', 'Worst_team_of_the_month', 'Worst_perc_as_chosen'])
        today_games_divstrat_df = today_games_divstrat_df

        sibyl_metrics_df['N_Today_games'] = n_today_games
        sibyl_metrics_df['N_Predictions_made'] = n_predictions_sofar
        sibyl_metrics_df['Sea_Perc_corr_pred'] = perc_correct_pred
        sibyl_metrics_df['Mean_Sibyl_conf_for_divstrat'] = mean_sibyl_conf_for_divstrat

        month_teams_df['Team_of_the_month'] = best_team_as_chosen
        month_teams_df['Best_percent_as_chosen'] = best_perc_as_chosen

        month_teams_df['Worst_team_of_the_month'] = worst_team_as_chosen
        month_teams_df['Worst_perc_as_chosen'] = worst_perc_as_chosen

        sibyl_metrics_df.loc[len(sibyl_metrics_df)] = [n_today_games, n_predictions_sofar, perc_correct_pred,
                                                       mean_sibyl_conf_for_divstrat]
        month_teams_df.loc[len(month_teams_df)] = [best_team_as_chosen, best_perc_as_chosen, worst_team_as_chosen,
                                                   worst_perc_as_chosen]

        sibyl_metrics_df.to_csv('Sibyl_metrics_US_SPORTS.csv', mode='w+', index=True)
        month_teams_df.to_csv('Month_teams_US_SPORTS.csv', mode='w+', index=True)
        today_games_divstrat_df.to_csv('today_games_divstrat_US_SPORTS.csv', mode='w+', index=True)

        self.sibyl_metrics_df = sibyl_metrics_df
        self.month_teams_df = month_teams_df
        self.today_games_divstrat_df = today_games_divstrat_df

if __name__ == '__main__':
    x = ModelMetricsUSSports(
    "us_sports_tableau_output.csv",\
    "us_sports_upcoming_matchups_us_p_df.csv",\
    "us_sports_team_names_list.csv")
    
    x()

# %%
x = ModelMetricsUSSports(
"us_sports_tableau_output.csv",\
"us_sports_upcoming_matchups_us_p_df.csv",\
"us_sports_team_names_list.csv")

x()

# %%
x.month_teams_df
# Out:
#        Team_of_the_month  Best_percent_as_chosen Worst_team_of_the_month  \
# 0  Columbus Blue Jackets                   92.86        Seattle Seahawks
#
#    Worst_perc_as_chosen
# 0                  60.0

# %%
x.us_sports_upco_df
# Out:
#            Bookies_choice  Confidence        Date Divergence_Y/N  Home_Odd  \
# 0                     CLE       0.521  2016-09-14              N      2.00
# 1                     HOU       0.502  2016-09-14              N      1.63
# 2                     ARI       0.515  2016-09-14              Y      1.76
# 3                     SEA       0.552  2016-09-14              N      2.26
# 4                     DET       0.674  2016-09-14              N      1.66
# 5                     CLE       0.521  2016-09-14              N      2.38
# 6                     PHI       0.536  2016-09-14              Y      1.87
# 7                     KCR       0.562  2016-09-14              N      1.64
# 8                     CHC       0.688  2016-09-15              N      1.47
# 9                     LAD       0.599  2016-09-15              N      2.80
# 10                    TOR       0.574  2016-09-15              N      2.46
# 11                    SFG       0.522  2016-09-15              N      1.62
# 12                    KCR       0.511  2016-09-16              N      1.77
# 13                    LAD       0.599  2016-09-16              N      2.40
# 14                    WSN       0.657  2016-09-16              N      3.97
# 15                    BOS       0.592  2016-09-16              N      1.85
# 16                    CHC       0.688  2016-09-16              N      1.61
# 17                    PIT       0.536  2016-09-16              N      2.36
# 18                    TBR       0.600  2016-09-16              Y      2.19
# 19                    COL       0.591  2016-09-17              N      1.75
# 20                    PIT       0.536  2016-09-17              N      2.42
# 21                    MIA       0.528  2016-09-17              N      2.15
# 22                    KCR       0.511  2016-09-17              N      1.82
# 23                    KCR       0.511  2016-09-17              N      1.63
# 0       Charlotte Hornets       0.647  2016-12-23              N      1.58
# 1           Orlando Magic       0.643  2016-12-23              N      1.46
# 2          Boston Celtics       0.681  2016-12-23              N      1.57
# 3           Brooklyn Nets       0.960  2016-12-23              Y      1.95
# 4   Golden State Warriors       0.783  2016-12-23              N      3.51
# 5         Houston Rockets       0.641  2016-12-23              N      2.36
# ..                    ...         ...         ...            ...       ...
# 12    Pittsburgh Steelers       0.642  2016-12-25              N      1.39
# 13     Kansas City Chiefs       0.639  2016-12-25              N      1.54
# 14         Dallas Cowboys       0.617  2016-12-26              N      1.35
# 0   Columbus Blue Jackets       0.615  2016-12-23              N      1.62
# 1      New York Islanders       0.587  2016-12-23              N      1.67
# 2        New York Rangers       0.588  2016-12-23              N      1.63
# 3     Pittsburgh Penguins       0.745  2016-12-23              N      1.42
# 4     Washington Capitals       0.651  2016-12-23              N      1.44
# 5     Carolina Hurricanes       0.513  2016-12-23              Y      1.89
# 6        Florida Panthers       0.578  2016-12-23              N      1.63
# 7      Chicago Blackhawks       0.808  2016-12-23              N      1.33
# 8            Dallas Stars       0.610  2016-12-23              Y      1.73
# 9     Toronto Maple Leafs       0.560  2016-12-23              N      2.21
# 10         Calgary Flames       0.629  2016-12-23              N      1.49
# 11        San Jose Sharks       0.643  2016-12-23              N      1.59
# 12  Columbus Blue Jackets       0.713  2016-12-27              N      2.18
# 13    Pittsburgh Penguins       0.656  2016-12-27              N      3.54
# 14    Washington Capitals       0.619  2016-12-27              N      3.01
# 15       New York Rangers       0.678  2016-12-27              N      1.96
# 16      Detroit Red Wings       0.589  2016-12-27              N      2.23
# 17    Nashville Predators       0.640  2016-12-27              Y      2.35
# 18     Chicago Blackhawks       0.714  2016-12-27              N      1.84
# 19           Dallas Stars       0.502  2016-12-27              Y      2.98
# 20         Calgary Flames       0.622  2016-12-27              N      2.59
# 21          Anaheim Ducks       0.567  2016-12-27              Y      2.38
# 22    Toronto Maple Leafs       0.562  2016-12-28              Y      1.37
# 23    Carolina Hurricanes       0.677  2016-12-28              Y      1.30
# 24     Montreal Canadiens       0.603  2016-12-28              N      1.47
# 25    Philadelphia Flyers       0.556  2016-12-28              Y      1.41
# 26      Los Angeles Kings       0.602  2016-12-28              N      1.69
#
#                 Home_Team  ID League  \
# 0                     CHW   0    MLB
# 1                     HOU   1    MLB
# 2                     ARI   2    MLB
# 3                     LAA   3    MLB
# 4                     DET   4    MLB
# 5                     CHW   5    MLB
# 6                     PHI   6    MLB
# 7                     KCR   7    MLB
# 8                     CHC   8    MLB
# 9                     ARI   9    MLB
# 10                    LAA  10    MLB
# 11                    SFG  11    MLB
# 12                    KCR  12    MLB
# 13                    ARI  13    MLB
# 14                    ATL  14    MLB
# 15                    BOS  15    MLB
# 16                    CHC  16    MLB
# 17                    CIN  17    MLB
# 18                    BAL  18    MLB
# 19                    COL  19    MLB
# 20                    CIN  20    MLB
# 21                    PHI  21    MLB
# 22                    KCR  22    MLB
# 23                    KCR  23    MLB
# 0       Charlotte Hornets   0    NBA
# 1           Orlando Magic   1    NBA
# 2          Boston Celtics   2    NBA
# 3     Cleveland Cavaliers   3    NBA
# 4         Detroit Pistons   4    NBA
# 5       Memphis Grizzlies   5    NBA
# ..                    ...  ..    ...
# 12    Pittsburgh Steelers  12    NFL
# 13     Kansas City Chiefs  13    NFL
# 14         Dallas Cowboys  14    NFL
# 0   Columbus Blue Jackets   0    NHL
# 1      New York Islanders   1    NHL
# 2        New York Rangers   2    NHL
# 3     Pittsburgh Penguins   3    NHL
# 4     Washington Capitals   4    NHL
# 5     Carolina Hurricanes   5    NHL
# 6        Florida Panthers   6    NHL
# 7      Chicago Blackhawks   7    NHL
# 8            Dallas Stars   8    NHL
# 9         Arizona Coyotes   9    NHL
# 10         Calgary Flames  10    NHL
# 11        San Jose Sharks  11    NHL
# 12  Columbus Blue Jackets  12    NHL
# 13      New Jersey Devils  13    NHL
# 14     New York Islanders  14    NHL
# 15       New York Rangers  15    NHL
# 16      Detroit Red Wings  16    NHL
# 17    Nashville Predators  17    NHL
# 18     Chicago Blackhawks  18    NHL
# 19        Arizona Coyotes  19    NHL
# 20     Colorado Avalanche  20    NHL
# 21          Anaheim Ducks  21    NHL
# 22       Florida Panthers  22    NHL
# 23    Pittsburgh Penguins  23    NHL
# 24    Tampa Bay Lightning  24    NHL
# 25        St. Louis Blues  25    NHL
# 26      Vancouver Canucks  26    NHL
#
#                                   Matchup_US_P                  Sibyl  \
# 0                                    CLE @ CHW                    CLE
# 1                                    TEX @ HOU                    HOU
# 2                                    COL @ ARI                    COL
# 3                                    SEA @ LAA                    SEA
# 4                                    MIN @ DET                    DET
# 5                                    CLE @ CHW                    CLE
# 6                                    PIT @ PHI                    PIT
# 7                                    OAK @ KCR                    KCR
# 8                                    MIL @ CHC                    CHC
# 9                                    LAD @ ARI                    LAD
# 10                                   TOR @ LAA                    TOR
# 11                                   STL @ SFG                    SFG
# 12                                   CHW @ KCR                    KCR
# 13                                   LAD @ ARI                    LAD
# 14                                   WSN @ ATL                    WSN
# 15                                   NYY @ BOS                    BOS
# 16                                   MIL @ CHC                    CHC
# 17                                   PIT @ CIN                    PIT
# 18                                   TBR @ BAL                    BAL
# 19                                   SDP @ COL                    COL
# 20                                   PIT @ CIN                    PIT
# 21                                   MIA @ PHI                    MIA
# 22                                   CHW @ KCR                    KCR
# 23                                   CHW @ KCR                    KCR
# 0            Chicago Bulls @ Charlotte Hornets      Charlotte Hornets
# 1           Los Angeles Lakers @ Orlando Magic          Orlando Magic
# 2       Oklahoma City Thunder @ Boston Celtics         Boston Celtics
# 3          Brooklyn Nets @ Cleveland Cavaliers    Cleveland Cavaliers
# 4      Golden State Warriors @ Detroit Pistons  Golden State Warriors
# 5          Houston Rockets @ Memphis Grizzlies        Houston Rockets
# ..                                         ...                    ...
# 12      Baltimore Ravens @ Pittsburgh Steelers    Pittsburgh Steelers
# 13         Denver Broncos @ Kansas City Chiefs     Kansas City Chiefs
# 14              Detroit Lions @ Dallas Cowboys         Dallas Cowboys
# 0   Montreal Canadiens @ Columbus Blue Jackets  Columbus Blue Jackets
# 1          Buffalo Sabres @ New York Islanders     New York Islanders
# 2            Minnesota Wild @ New York Rangers       New York Rangers
# 3      New Jersey Devils @ Pittsburgh Penguins    Pittsburgh Penguins
# 4    Tampa Bay Lightning @ Washington Capitals    Washington Capitals
# 5          Boston Bruins @ Carolina Hurricanes          Boston Bruins
# 6         Detroit Red Wings @ Florida Panthers       Florida Panthers
# 7      Colorado Avalanche @ Chicago Blackhawks     Chicago Blackhawks
# 8             Los Angeles Kings @ Dallas Stars      Los Angeles Kings
# 9        Toronto Maple Leafs @ Arizona Coyotes    Toronto Maple Leafs
# 10          Vancouver Canucks @ Calgary Flames         Calgary Flames
# 11           Edmonton Oilers @ San Jose Sharks        San Jose Sharks
# 12       Boston Bruins @ Columbus Blue Jackets  Columbus Blue Jackets
# 13     Pittsburgh Penguins @ New Jersey Devils    Pittsburgh Penguins
# 14    Washington Capitals @ New York Islanders    Washington Capitals
# 15          Ottawa Senators @ New York Rangers       New York Rangers
# 16          Buffalo Sabres @ Detroit Red Wings      Detroit Red Wings
# 17        Minnesota Wild @ Nashville Predators         Minnesota Wild
# 18          Winnipeg Jets @ Chicago Blackhawks     Chicago Blackhawks
# 19              Dallas Stars @ Arizona Coyotes        Arizona Coyotes
# 20         Calgary Flames @ Colorado Avalanche         Calgary Flames
# 21             San Jose Sharks @ Anaheim Ducks        San Jose Sharks
# 22      Toronto Maple Leafs @ Florida Panthers       Florida Panthers
# 23   Carolina Hurricanes @ Pittsburgh Penguins    Pittsburgh Penguins
# 24    Montreal Canadiens @ Tampa Bay Lightning     Montreal Canadiens
# 25       Philadelphia Flyers @ St. Louis Blues        St. Louis Blues
# 26       Los Angeles Kings @ Vancouver Canucks      Los Angeles Kings
#
#         Time True_Result  Visitor_Odd           Visitor_Team
# 0      00:10    Upcoming         1.87                    CLE
# 1      00:10    Upcoming         2.37                    TEX
# 2      01:40    Upcoming         2.13                    COL
# 3      02:05    Upcoming         1.68                    SEA
# 4      17:10    Upcoming         2.29                    MIN
# 5      18:10    Upcoming         1.62                    CLE
# 6      23:05    Upcoming         1.97                    PIT
# 7      23:15    Upcoming         2.33                    OAK
# 8      00:05    Upcoming         2.76                    MIL
# 9      01:40    Upcoming         1.46                    LAD
# 10     02:05    Upcoming         1.58                    TOR
# 11     02:15    Upcoming         2.37                    STL
# 12     00:15    Upcoming         2.15                    CHW
# 13     01:40    Upcoming         1.63                    LAD
# 14     17:05    Upcoming         1.28                    WSN
# 15     17:05    Upcoming         2.04                    NYY
# 16     20:05    Upcoming         2.45                    MIL
# 17     22:10    Upcoming         1.65                    PIT
# 18     23:05    Upcoming         1.74                    TBR
# 19     00:10    Upcoming         2.18                    SDP
# 20     17:10    Upcoming         1.62                    PIT
# 21     17:35    Upcoming         1.77                    MIA
# 22     18:15    Upcoming         2.08                    CHW
# 23     18:15    Upcoming         2.37                    CHW
# 0   20:00:00    Upcoming         2.42          Chicago Bulls
# 1   20:00:00    Upcoming         2.77     Los Angeles Lakers
# 2   20:30:00    Upcoming         2.44  Oklahoma City Thunder
# 3   20:30:00    Upcoming         1.95          Brooklyn Nets
# 4   20:30:00    Upcoming         1.31  Golden State Warriors
# 5   21:00:00    Upcoming         1.61        Houston Rockets
# ..       ...         ...          ...                    ...
# 12  17:30:00    Upcoming         3.06       Baltimore Ravens
# 13  21:30:00    Upcoming         2.50         Denver Broncos
# 14  21:30:00    Upcoming         3.27          Detroit Lions
# 0   20:00:00    Upcoming         2.29     Montreal Canadiens
# 1   20:00:00    Upcoming         2.20         Buffalo Sabres
# 2   20:00:00    Upcoming         2.27         Minnesota Wild
# 3   20:00:00    Upcoming         2.85      New Jersey Devils
# 4   20:00:00    Upcoming         2.79    Tampa Bay Lightning
# 5   20:30:00    Upcoming         1.91          Boston Bruins
# 6   20:30:00    Upcoming         2.28      Detroit Red Wings
# 7   21:30:00    Upcoming         3.27     Colorado Avalanche
# 8   21:30:00    Upcoming         2.10      Los Angeles Kings
# 9   22:00:00    Upcoming         1.67    Toronto Maple Leafs
# 10  22:00:00    Upcoming         2.63      Vancouver Canucks
# 11  23:30:00    Upcoming         2.37        Edmonton Oilers
# 12  20:00:00    Upcoming         2.95          Boston Bruins
# 13  20:00:00    Upcoming         1.94    Pittsburgh Penguins
# 14  20:00:00    Upcoming         2.14    Washington Capitals
# 15  20:00:00    Upcoming         3.42        Ottawa Senators
# 16  20:30:00    Upcoming         2.89         Buffalo Sabres
# 17  21:00:00    Upcoming         2.73         Minnesota Wild
# 18  21:30:00    Upcoming         3.96          Winnipeg Jets
# 19  22:00:00    Upcoming         2.19           Dallas Stars
# 20  22:00:00    Upcoming         2.43         Calgary Flames
# 21  23:00:00    Upcoming         2.66        San Jose Sharks
# 22  20:00:00    Upcoming         1.28    Toronto Maple Leafs
# 23  20:00:00    Upcoming         1.28    Carolina Hurricanes
# 24  20:30:00    Upcoming         1.28     Montreal Canadiens
# 25  21:00:00    Upcoming         1.28    Philadelphia Flyers
# 26  23:00:00    Upcoming         1.28      Los Angeles Kings
#
# [80 rows x 14 columns]
